# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import networkx as nx
import seaborn as sns

# %%
df = pd.read_csv('/mnt/storage/University/Social Networks/Homeworks/Final Project/final_demo/part2.csv')

# %% [markdown]
# # Question 1:

# %%
df
# Out:
#                         Id           Label  tweets  replies  retweets  quotes  \
# 0                     7552       Pitpitak1     278        6        23       7
# 1                   742143        BBCWorld      11        0         0       0
# 2                   764537      AminSabeti     486       78       479     349
# 3                   787430           Hamed      72        4        12      46
# 4                   788524    guardiannews      15        0         0       0
# ...                    ...             ...     ...      ...       ...     ...
# 24115  1591408864154484736        enyooone       5       18         7       4
# 24116  1591630199476473856    madaresattar      13        0         3       0
# 24117  1591674283591335936     MehdiReza18       7        8         4       2
# 24118  1592173905682333699    komando_sexy       7        0         2       0
# 24119  1592672663490924544  mmmorvaaariddd       8       11        25       0
#
# ...

# %%
sorted  = df.sort_values(by='tweets',ascending=False).iloc[:10]

# %%
plt.figure(figsize=(15,5))
plt.bar(sorted['Label'],sorted['tweets'])
for i in range(10):
    plt.text(sorted['Label'].iloc[i], sorted['tweets'].iloc[i]/2,sorted['tweets'].iloc[i],  ha = 'center')
plt.title('Top 10 Accounts Based on tweets',size=14)
plt.xticks(rotation=30)
plt.ylabel('tweets',size=12)
plt.show()

# %%
sorted  = df.sort_values(by='retweets',ascending=False).iloc[:10]
plt.figure(figsize=(15,5))
plt.bar(sorted['Label'],sorted['retweets'])
for i in range(10):
    plt.text(sorted['Label'].iloc[i], sorted['retweets'].iloc[i]/2,sorted['retweets'].iloc[i],  ha = 'center')
plt.title('Top 10 Accounts Based on retweets',size=14)
plt.xticks(rotation=30)
plt.ylabel('retweets',size=12)
plt.show()

# %%
sorted  = df.sort_values(by='replies',ascending=False).iloc[:10]
plt.figure(figsize=(15,5))
plt.bar(sorted['Label'],sorted['replies'])
for i in range(10):
    plt.text(sorted['Label'].iloc[i], sorted['replies'].iloc[i]/2,sorted['replies'].iloc[i],  ha = 'center')
plt.title('Top 10 Accounts Based on replies',size=14)
plt.xticks(rotation=30)
plt.ylabel('replies',size=12)
plt.show()

# %%
sorted  = df.sort_values(by='quotes',ascending=False).iloc[:10]
plt.figure(figsize=(15,5))
plt.bar(sorted['Label'],sorted['quotes'])
for i in range(10):
    plt.text(sorted['Label'].iloc[i], sorted['quotes'].iloc[i]/2,sorted['quotes'].iloc[i],  ha = 'center')
plt.title('Top 10 Accounts Based on quotes',size=14)
plt.xticks(rotation=30)
plt.ylabel('quotes',size=12)
plt.show()

# %%
sorted  = df.sort_values(by='impression',ascending=False).iloc[:10]
plt.figure(figsize=(15,5))
plt.bar(sorted['Label'],sorted['impression'])
for i in range(10):
    plt.text(sorted['Label'].iloc[i], sorted['impression'].iloc[i]/2,sorted['impression'].iloc[i],  ha = 'center')
plt.title('Top 10 Accounts Based on impression',size=14)
plt.xticks(rotation=30)
plt.ylabel('impression',size=12)
plt.show()

# %%
sorted  = df.sort_values(by='activity',ascending=False).iloc[:10]
plt.figure(figsize=(15,5))
plt.bar(sorted['Label'],sorted['activity'])
for i in range(10):
    plt.text(sorted['Label'].iloc[i], sorted['activity'].iloc[i]/2,sorted['activity'].iloc[i],  ha = 'center')
plt.title('Top 10 Accounts Based on activity',size=14)
plt.xticks(rotation=30)
plt.ylabel('activity',size=12)
plt.show()

# %%
sorted  = df.sort_values(by='reaction',ascending=False).iloc[:10]
plt.figure(figsize=(15,5))
plt.bar(sorted['Label'],sorted['reaction'])
for i in range(10):
    plt.text(sorted['Label'].iloc[i], sorted['reaction'].iloc[i]/2,sorted['reaction'].iloc[i],  ha = 'center')
plt.title('Top 10 Accounts Based on reaction',size=14)
plt.xticks(rotation=30)
plt.ylabel('reaction',size=12)
plt.show()

# %%
sorted  = df.sort_values(by='followers',ascending=False).iloc[:10]
plt.figure(figsize=(15,5))
plt.bar(sorted['Label'],sorted['followers'])
for i in range(10):
    plt.text(sorted['Label'].iloc[i], sorted['followers'].iloc[i]/2,sorted['followers'].iloc[i],  ha = 'center')
plt.title('Top 10 Accounts Based on followers',size=14)
plt.xticks(rotation=30)
plt.ylabel('followers',size=12)
plt.show()

# %%
sorted  =  {'bbcpersian':
2107386,
'VOAfarsi':
1661372,
'alikarimi_ak8':
1450184,
'IranIntl':
1363341,
'dw_persian':
1147066,
'RadioFarda_':
1126780,
'IranIntlbrk':
1119258,
'ManotoNews':
1071549,
'manototv':
1062780,
'sinavaliollah':
1052573}

plt.figure(figsize=(15,5))
plt.bar(sorted.keys(),sorted.values())
for i in sorted.keys():
    plt.text(i, sorted[i]/2,sorted[i],  ha = 'center')
plt.title('Top 10 Persian Accounts Based on followers',size=14)
plt.xticks(rotation=30)
plt.ylabel('followers',size=12)
plt.show()

# %%
sorted  = df.sort_values(by=['retweets','replies','quotes','impression','activity','reaction','followers','tweets']\
    ,ascending=False).iloc[:10]
label = sorted['Label']
sorted = sorted[['tweets','retweets','replies','quotes','impression','activity','reaction','followers']]
sorted = (sorted - sorted.min())/(sorted.max() - sorted.min())
sorted['Label'] = label
sorted = sorted.iloc[:10]
sorted
# Out:
#          tweets  retweets   replies    quotes  impression  activity  reaction  \
# 6909   0.307528  1.000000  0.135857  0.000000    1.000000  1.000000  1.000000
# 18536  0.936080  0.545011  0.390869  1.000000    0.931016  0.727327  0.648602
# 17796  0.671875  0.328645  0.043430  0.020640    0.811046  0.337183  0.287194
# 2131   0.115057  0.276270  0.164811  0.898865    0.931350  0.307409  0.324819
# 11340  0.855114  0.227950  0.898664  0.321981    0.903815  0.411533  0.339921
# 19748  0.113636  0.164488  1.000000  0.079463    0.781285  0.252053  0.269158
# 10439  0.387784  0.136439  0.268374  0.012384    0.716678  0.138090  0.120901
# 14276  1.000000  0.088036  0.000000  0.023736    0.000000  0.121492  0.029772
# 9825   0.000000  0.081665  0.224944  0.263158    0.959668  0.048854  0.078012
# 13784  0.236506  0.000000  0.390869  0.041280    0.398793  0.000000  0.000000
#
#        followers            Label
# 6909    0.116481       abanzb1991
# 18536   0.389560    Therealmamad2
# ...

# %% [markdown]
# # Question 2:

# %%
import seaborn as sns

# %%
df.columns
# Out:
# Index(['Id', 'Label', 'tweets', 'replies', 'retweets', 'quotes', 'followers',
#        'impression', 'age', 'activedays', 'reaction', 'activity', 'robot',
#        'btsexo', 'Authority', 'Hub', 'pageranks', 'indegree', 'outdegree',
#        'Degree'],
#       dtype='object')

# %%
correlation_matrix = df[['impression','activity','followers','Authority','Hub','pageranks','indegree','outdegree']].corr()
plt.figure(figsize=(12,10))
sns.heatmap(correlation_matrix, annot=True,vmin=-1,vmax=1,center=0)

# %%
sorted  = df.sort_values(by='Hub',ascending=False).iloc[:10]
plt.figure(figsize=(15,5))
plt.bar(sorted['Label'],sorted['Hub'])
for i in range(10):
    plt.text(sorted['Label'].iloc[i], sorted['Hub'].iloc[i]/2,sorted['Hub'].iloc[i],  ha = 'center')
plt.title('Top 10 Accounts Based on Hub',size=14)
plt.xticks(rotation=30)
plt.ylabel('Hub',size=12)
plt.show()

# %%
sorted  = df.sort_values(by='Authority',ascending=False).iloc[:10]
plt.figure(figsize=(15,5))
plt.bar(sorted['Label'],sorted['Authority'])
for i in range(10):
    plt.text(sorted['Label'].iloc[i], sorted['Authority'].iloc[i]/2,sorted['Authority'].iloc[i],  ha = 'center')
plt.title('Top 10 Accounts Based on Authority',size=14)
plt.xticks(rotation=30)
plt.ylabel('Authority',size=12)
plt.show()

# %%
sorted  = df.sort_values(by='indegree',ascending=False).iloc[:10]
plt.figure(figsize=(15,5))
plt.bar(sorted['Label'],sorted['indegree'])
for i in range(10):
    plt.text(sorted['Label'].iloc[i], sorted['indegree'].iloc[i]/2,sorted['indegree'].iloc[i],  ha = 'center')
plt.title('Top 10 Accounts Based on In Degree',size=14)
plt.xticks(rotation=30)
plt.ylabel('In Degree',size=12)
plt.show()

# %%
sorted  = df.sort_values(by='pageranks',ascending=False).iloc[:10]
plt.figure(figsize=(15,5))
plt.bar(sorted['Label'],sorted['pageranks'])
for i in range(10):
    plt.text(sorted['Label'].iloc[i], sorted['pageranks'].iloc[i]/2,sorted['pageranks'].iloc[i],  ha = 'center')
plt.title('Top 10 Accounts Based on Page Ranks',size=14)
plt.xticks(rotation=30)
plt.ylabel('Page Ranks',size=12)
plt.show()

# %%
sorted  = df.sort_values(by=['pageranks','Hub','Authority','indegree'],ascending=False)
label = sorted['Label']
sorted = sorted[['pageranks','Hub','Authority','indegree']]
sorted = (sorted - sorted.min())/(sorted.max() - sorted.min())
sorted['Label'] = label
sorted = sorted.iloc[:10]
sorted
# Out:
#        pageranks       Hub  Authority  indegree           Label
# 3343    1.000000  0.001945   0.474399  0.346826        IranIntl
# 6353    0.859173  0.006155   0.149863  0.077408   iranintlsport
# 11206   0.450120  0.025507   0.892188  0.788803      1500tasvir
# 9103    0.399009  0.035306   0.982085  0.927323        OutFarsi
# 935     0.380765  0.028831   0.968183  0.870679      mamadporii
# 15039   0.364025  0.000000   1.000000  1.000000    F_karamizand
# 14459   0.249231  0.045056   0.828873  0.626232       myfootkin
# 19170   0.235463  0.041535   0.690247  0.448811  1Herculepoirot
# 1746    0.218278  0.000492   0.897851  0.732291   pouriazeraati
# 1461    0.217287  0.032475   0.695534  0.508214    khiyar_shoor

# %% [markdown]
# # Question 3:

# %%
G = nx.read_graphml('./final_demo/undirected.graphml')
k_shell = nx.core_number(G)
nx.set_node_attributes(G,k_shell,'k_shell')
nx.write_graphml(G,'./final_demo/graph_with_kshell.graphml')

# %%
names= ['id','label','k_shell','btsexo','robot','activity','reaction','activedays','age','impression','followers','quotes','retweets','replies','tweets']
df = pd.read_csv('./final_demo/attributes_with_kshell.csv')
df.columns = names

# %%
df
# Out:
#                         id           label  k_shell  btsexo  robot  activity  \
# 0                     7552       Pitpitak1        9       0  0.016       314
# 1                   742143        BBCWorld        0       0  0.000        11
# 2                   764537      AminSabeti      112       0  0.040      1392
# 3                   787430           Hamed       18       0  0.029       134
# 4                   788524    guardiannews        0       0  0.000        15
# ...                    ...             ...      ...     ...    ...       ...
# 24115  1591408864154484736        enyooone        1       0  0.000        34
# 24116  1591630199476473856    madaresattar       21       0  0.000        16
# 24117  1591674283591335936     MehdiReza18        0       0  0.000        21
# 24118  1592173905682333699    komando_sexy        0       0  0.000         9
# 24119  1592672663490924544  mmmorvaaariddd        2       0  0.000        44
#
# ...

# %%
correlation_matrix = df.drop(labels='id',axis=1).corr()
plt.figure(figsize=(12,10))
sns.heatmap(correlation_matrix, annot=True,vmin=-1,vmax=1,center=0)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(8,6))
plt.ylabel('Number')
plt.xlabel('K shell')
plt.hist(df['k_shell'],bins=124);

# %%
plt.figure(figsize=(8,6))
plt.ylabel('Number')
label = 'robot'
plt.xlabel(label)
plt.hist(df[label],64);

# %%
plt.figure(figsize=(8,6))
plt.ylabel('Number')
label = 'robot'
plt.xlabel(label)
plt.hist(df.loc[df['k_shell']==124,label],64);

# %% [markdown]
# # Question 5

# %%
df = pd.read_csv('./final_demo/infomap.csv')
names= ['id','label','infomap','modularity_class','btsexo','robot','activity','reaction','activedays','age','impression','followers','quotes','retweets','replies','tweets']
df.columns = names

# %%
df
# Out:
#                         id           label  infomap  modularity_class  btsexo  \
# 0                     7552       Pitpitak1        1               337       0
# 1                   742143        BBCWorld     2898                 0       0
# 2                   764537      AminSabeti        1               337       0
# 3                   787430           Hamed        1               337       0
# 4                   788524    guardiannews     2899                 1       0
# ...                    ...             ...      ...               ...     ...
# 24115  1591408864154484736        enyooone       69              1270       0
# 24116  1591630199476473856    madaresattar        1               199       0
# 24117  1591674283591335936     MehdiReza18     1763              3319       0
# 24118  1592173905682333699    komando_sexy     1764              3320       0
# 24119  1592672663490924544  mmmorvaaariddd        1               162       0
#
# ...

# %%
louvian = (df.groupby(by='modularity_class').count()).sort_values(by='id',ascending=False)[:10]

# %%
infomap = (df.groupby(by='infomap').count()).sort_values(by='id',ascending=False)[:10]

# %%
infomap
# Out:
#            id  label  modularity_class  btsexo  robot  activity  reaction  \
# infomap
# 1        8821   8821              8821    8821   8821      8821      8821
# 2        1370   1370              1370    1370   1370      1370      1370
# 3         871    871               871     871    871       871       871
# 5         702    702               702     702    702       702       702
# 18        570    570               570     570    570       570       570
# 4         525    525               525     525    525       525       525
# 6         456    456               456     456    456       456       456
# 12        438    438               438     438    438       438       438
# 10        412    412               412     412    412       412       412
# 7         383    383               383     383    383       383       383
#
#          activedays   age  impression  followers  quotes  retweets  replies  \
# infomap
# ...

# %%
plt.figure(figsize=(8,5))

plt.bar(np.arange(1,11),infomap['id'])
plt.xticks(np.arange(1,11))
plt.title("Infomap Cluster Size")
plt.ylabel("Number of Nodes")
plt.xlabel("Cluster")
plt.show()

# %%
plt.figure(figsize=(8,5))

plt.bar(np.arange(1,11),louvian['id'])
plt.xticks(np.arange(1,11))
plt.title("Louvian Cluster Size")
plt.ylabel("Number of Nodes")
plt.xlabel("Cluster")
plt.show()

# %%
infomap.index
# Out:
# Int64Index([1, 2, 3, 5, 18, 4, 6, 12, 10, 7], dtype='int64', name='infomap')

# %%
louvian.index
# Out:
# Int64Index([1270, 162, 337, 2591, 1966, 810, 2395, 199, 541, 1768], dtype='int64', name='modularity_class')

# %%
louvian
# Out:
#                     id  label  infomap  btsexo  robot  activity  reaction  \
# modularity_class
# 1270              5643   5643     5643    5643   5643      5643      5643
# 162               4535   4535     4535    4535   4535      4535      4535
# 337               3739   3739     3739    3739   3739      3739      3739
# 2591              2533   2533     2533    2533   2533      2533      2533
# 1966              1299   1299     1299    1299   1299      1299      1299
# 810                945    945      945     945    945       945       945
# 2395               695    695      695     695    695       695       695
# 199                560    560      560     560    560       560       560
# 541                416    416      416     416    416       416       416
# 1768                95     95       95      95     95        95        95
#
#                   activedays   age  impression  followers  quotes  retweets  \
# modularity_class
# ...

# %%
len(btsexo.keys())
# Out:
# 10

# %% [markdown]
# # Question 6

# %%
plt.figure(figsize=(15,8))
plt.bar(btsexo.keys(),btsexo.values(),width=30.0)
plt.xticks(louvian.index,louvian.index,rotation=45,size=8)
plt.title("Average btsexo for Top 10 Clusters",size=14)
plt.ylabel("Average")
plt.xlabel("Cluster Number")
plt.show()

# %%
df.loc[df['modularity_class']==louvian.index[0],'robot']
# Out:
# 155      0.042
# 233      0.047
# 242      0.017
# 270      0.030
# 372      0.029
#          ...
# 24094    0.000
# 24097    0.000
# 24104    0.000
# 24108    0.000
# 24115    0.000
# Name: robot, Length: 5643, dtype: float64

# %%
plt.figure(figsize=(15,8))
plt.bar(louvian.index+15.0,df.groupby('modularity_class').mean().loc[louvian.index,'robot'],width=30.0,label='Robot')
plt.bar(louvian.index -15.0,df.groupby('modularity_class').mean()['btsexo'].loc[louvian.index],width=30.0,label='Btsexo')
plt.xticks(louvian.index,louvian.index,rotation=45,size=8)
plt.title("Average Robot and BTSexo for Top 10 Clusters",size=14)
plt.ylabel("Average")
plt.xlabel("Cluster Number")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(13,8))
plt.boxplot([df.loc[df['modularity_class']==cluster,'robot'] for cluster in louvian.index])
plt.xticks(np.arange(1,11),louvian.index)
plt.title('Robot Probability Boxplot in Clusters')
plt.ylabel("Probability")
plt.xlabel("Cluster")
plt.show()

# %%
df_filtered = df.loc[df['modularity_class'].isin(louvian.index)]

# %%
plt.figure(figsize=(20,6))
sns.violinplot(x=df_filtered['modularity_class'],y = df_filtered['robot'])
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.hist(df.loc[df['modularity_class']==2591,'robot'],bins=np.arange(0,1,0.01));
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.hist(df.loc[df['modularity_class']==2395,'robot'],bins=np.arange(0,1,0.01));
plt.show()

# %% [markdown]
# # Question 7

# %%
age = df.loc[df['age']<=64].groupby('modularity_class').count() / df.groupby('modularity_class').count()

# %%
plt.figure(figsize=(10,5))
plt.bar(louvian.index,age.loc[louvian.index,'id'],width=25)
plt.xticks(louvian.index,louvian.index,rotation=45,size=8)
plt.title('Young Accounts Percentage')
plt.ylabel("Percentage")
plt.xlabel('Cluster')
plt.show()

# %% [markdown]
# # Question 8

# %%
activedays = df.groupby('modularity_class')['activedays'].mean()

# %%
activedays = activedays.sort_values(ascending=False).loc[louvian.index]
plt.figure(figsize=(10,5))
plt.bar(louvian.index,activedays,width=25)
plt.xticks(louvian.index,louvian.index,rotation=45,size=8)
plt.title('Activedays for Top 10 Biggest Clusters')
plt.ylabel("Active Days")
plt.xlabel('Cluster')
plt.grid()
plt.show()
